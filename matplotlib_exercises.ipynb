# %%
#Use matplotlib to plot the following equation:

#You'll need to write the code that generates the x and y points.

#Add an anotation for the point 0, 0, the origin.

# %%
import random
import math
import matplotlib.pyplot as plt
from env import get_db_url
from random import randint
from pydataset import data
import pandas as pd
import numpy as np

# %%
#1
x = range(-100, 100)
y = [(x**2- x+2) for x in x]
plt.plot(x,y)


plt.axhline(y=0, xmin=0, xmax=1, linewidth=4, ls = '--', color='r')
plt.scatter(x, y)
plt.title('matplotlib')
plt.text(0, 0, 'origin')
plt.annotate('origin',xy=(0, 0), xytext=(0, 2000), arrowprops = dict(facecolor = 'gray')  )
# Out:
# Text(0, 2000, 'origin')

# %%
#2
x = range(-100, 100)
y = square root for x in x]

# %%
#2
x = range(-100, 100)
y = [(x**3) for x in x]
plt.plot(x,y)

# %%
#2
x = range(-100, 100)
y = [(2**x) for x in x]
plt.plot(x,y)

# %%
#2
x = range(-100, 100)
y = [(x+1) for x in x]
plt.plot(x,y)

# %%
#3

a = range(-100, 100)
b = [(a**2- a+2) for a in a]

x = range(-100, 100)
y = [(x**3) for x in x]

r = range(-100, 100)
s = [(2**r) for r in r]


# plot the first subplot
plt.subplot(121)
plt.plot(a, b)
plt.title('one')

# the second subplot
plt.subplot(122)
plt.plot(x, y)
plt.title('two')

# the third subplot
#plt.subplot(124)
#plt.plot(r, s)
#plt.title('three')

# the third subplot
#plt.subplot(125)
#plt.plot(r, s)
#plt.title('four')

plt.show()

# %%
#3
plt.figure(figsize = (10,6))

#subplot 1
plt.subplot(2,2,1)

plt.plot(x1,y1)

plt.title('$ y = \sqrt{x}$')
plt.xlabel('$x$')
plt.ylabel('$\sqrt{x}$')
plt.xlim(0,100)
plt.ylim(0, 10)
plt.grid(True, ls = '--')

#subplot 2
plt.subplot(222)

plt.plot(x2,y2)

plt.title('$ y = x^3$')
plt.xlabel('$x$')
plt.ylabel('$x^3$')
plt.xticks(range(0,20,5))
plt.xlim(0,20)
plt.ylim(0)
plt.grid(True, ls = '--')


#subplot 3
plt.subplot(223)

plt.plot(x3,y3)
plt.grid(True, ls = '--')
plt.xlabel('$x$')
plt.ylabel('$2^x$')
plt.title('$y = 2^x$')

#subplot 4
plt.subplot(224)

plt.plot(x4,y4)
plt.title(r'$ y = \frac{1}{x+1}$')
plt.xlabel('$x$')
plt.ylabel(r'$\frac{1}{x+1}$')
plt.grid(True, ls = '--')
plt.xlim(0,15)
plt.ylim(0)


plt.tight_layout()
# Out:
# Jupyter cannot be started. Error attempting to locate Jupyter: Running cells with 'Python 3.8.9 64-bit' requires jupyter and notebook package.
#
# Run the following command to install 'jupyter and notebook' into the Python environment.
#
# Command: 'python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U'
#
# Click <a href='https://aka.ms/installJupyterForVSCode'>here</a> for more info.

# %%
#4
plt.figure(figsize = (8,6))

# plot the data
plt.plot(x1, y1, c='#30a2da', label='$\sqrt{x}$', alpha=1.0)
plt.plot(x2, y2, c='orange', label='$x^{3}$', alpha=.8)
plt.plot(x3, y3, c= (1,0,1), label='$2^{x}$', alpha=.8)
plt.plot(x4, y4, c= '#444444', label='$1/(x+1)$', alpha=.8)

# adjust xlim and ylim
plt.ylim(0, 10)
plt.xlim(0, 10)

plt.ylabel('$y$')
plt.xlabel('$x$')
plt.title('My Functions')
plt.legend()

plt.show()
